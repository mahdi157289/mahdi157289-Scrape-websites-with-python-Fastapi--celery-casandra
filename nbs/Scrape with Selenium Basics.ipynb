# %%
# !cd
# %cd /Users/bacca/Desktop/Scrape-Websites-with-Python-FastAPI-Celery-NoSQL/
# Out:
# C:\Users\bacca\Desktop\Scrape-Websites-with-Python-FastAPI-Celery-NoSQL\nbs
# C:\Users\bacca\Desktop\Scrape-Websites-with-Python-FastAPI-Celery-NoSQL

# %%
import requests
from app import scraper


url = "https://www.amazon.com/ASUS-Display-NVIDIA%C2%AE-i7-13650HX-G614JV-AS74/dp/B0CRDCXRK2/ref=sr_1_1?_encoding=UTF8&content-id=amzn1.sym.860dbf94-9f09-4ada-8615-32eb5ada253a&dib=eyJ2IjoiMSJ9.YXOHQK4jgmiqqegAuE80p86D5O8D9cY4DY0akYfOWP4t4xJvsA9k6jvC2cQZKi7cap1Scy9nksS0_rPivJGhXw8qpGbN1raCGUh8__TRYdhaWBvFmI_ZD7goC4j6HKhJuN9LDj7yhKXHapLNBnkrzZN6x90cdMGtqpOE9dzW9_D_pWFGyym8dJpARq-ix3wKlyO80bIMlKCqydiCERTwU1zCLxRNUVmrbOh4PpZdNqgJGjnVCu3maHwEmPN85zB-Ov2xcTpngQemxGpJ2v-PogbJYiWkm48_pfQQdfe_Y1M.OAanpTzZ1tvvwz4_Vv7zbJgMmtuj2MV1_jdEu4WGZJY&dib_tag=se&keywords=gaming&pd_rd_r=93708429-24e7-4bb1-a540-4aa5feb7c941&pd_rd_w=8s9s5&pd_rd_wg=fb1wu&qid=1745405894&sr=8-1"
s = scraper.Scraper(url=url,endless_scroll=True )
s.get()
# Out:
# '<html lang="en-us" class="a-touch a-mobile a-ws a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-ios a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null awa-browser" data-19ax5a9jf="mongoose" data-aui-build-date="3.25.2-2025-04-17"><!-- sp:feature:head-start --><head><script async="" src="https://c.amazon-adsystem.com/bao-csm/forensics/a9-tq-forensics-incremental.min.js" crossorigin="anonymous"></script><script async="" src="https://images-na.ssl-images-amazon.com/images/I/31LJlqRcizL.js" crossorigin="anonymous"></script><style class="vjs-styles-defaults">\n      .video-js {\n        width: 300px;\n        height: 150px;\n      }\n\n      .vjs-fluid {\n        padding-top: 56.25%\n      }\n    </style><script>var aPageStart = (new Date()).getTime();</script><meta name="viewp
# ...

# %%
r = requests.get(url)
r.text
# Out:
# '<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(
# ...
